# %% [markdown]
# > Python Questions
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>import numpy as np</p>
# <p><em># 1. Write a Python function that finds the maximum value in a
# list</em></p>
# <p>data = [1,2,10, 3,15,4,5]</p>
# <p>max = data[0]</p>
# <p>for j in data:<br />
# if j&gt;max:<br />
# max=j</p>
# <p>print(max)</p>
# <p>15</p>
# <p><em># 2. Given a dictionary, return a list of its keys sorted by
# their values</em></p>
# <p>data = {"a":5, "b":2, "c":3, "d":10}</p>
# <p>keys = list(data.keys())<br />
# values = [data[k] for k in keys]<br />
# sorted_indices = np.argsort(values)</p>
# <p>sorted_keys = [keys[index] for index in sorted_indices]</p>
# <p>print(sorted_keys)</p>
# <p>['b', 'c', 'a', 'd']</p>
# <p><em># 3. Given an array of integers nums and an integer target,
# return indices of the two numbers</em><br />
# <em># such that they add up to target.</em></p>
# <p><em># Input: nums = [2,7,11,15], target = 9 # Output: [0,1]</em></p>
# <p>data = [2,7,11,15]<br />
# target = 9</p>
# <p>store={}<br />
# for index, j inenumerate(data):<br />
# diff = target-j<br />
# if diff notin store:<br />
# store[j]=diff</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>else:<br />
# print([index, data.index(diff)])</p>
# <p>[1, 0]</p>
# <p><em># 4. Sort array using bubble sort algorithm</em></p>
# <p>data = [3,4,1,8,7]</p>
# <p>n = len(data)<br />
# for i inrange(n): <em># suppose i=3, then last 3 elements should already
# be sorted</em><br />
# for j inrange(0, n-i-1): <em># j --&gt; 0 to 1</em><br />
# if data[j]&gt;data[j+1]:<br />
# data[j], data[j+1] = data[j+1], data[j]</p>
# <p>print(data)</p>
# <p>[1, 3, 4, 7, 8]</p>
# <p><em># 5. Sort array using quick sort algorithm</em></p>
# <p>data = [3,4,1,8,7]</p>
# <p>def quick_sort(data):<br />
# iflen(data)&lt;=1:<br />
# return data<br />
# pivot = data[0] <em># pick first element as pivot</em> left = [j for j
# in data[1:] if j&lt;pivot]<br />
# right = [j for j in data[1:] if j&gt;=pivot]</p>
# <p>return quick_sort(left) + [pivot] + quick_sort(right)</p>
# <p>quick_sort(data)</p>
# <p>[1, 3, 4, 7, 8]</p>
# <p><em># 6. Given an integer array nums, return all the triplets
# [nums[i], nums[j], nums[k]]</em><br />
# <em># such that i != j, i != k, and j != k, and nums[i] + nums[j] +
# nums[k] == 0</em></p>
# <p>original_nums = [-1,0,1,2,-1,-4]</p>
# <p>nums = quick_sort(original_nums)<br />
# result = []</p>
# <p>for index,elem inenumerate(nums):<br />
# left = index+1<br />
# right = len(nums)-1<br />
# while left&lt;right:<br />
# print("Current values, \n\tindex --&gt; {}, left_index --&gt; {},</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>right_index --&gt; {}".format(index, left, right))<br />
# total = elem + nums[left] + nums[right]<br />
# if total == 0:<br />
# if [elem, nums[left], nums[right]] notin result: result.append([elem,
# nums[left], nums[right]])</p>
# <p><em># check for any duplicates</em><br />
# while (left&lt;right) and (nums[left]==nums[left+1]): left =
# left+1<br />
# while (left&lt;right) and (nums[right]==nums[right-1]): right =
# right-1</p>
# <p>left = left+1<br />
# right = right-1<br />
# elif total &lt; 0:<br />
# left = left+1<br />
# else:<br />
# right = right-1</p>
# <p>print(result)</p>
# <p>Current values,<br />
# index --&gt; 0, left_index --&gt; 1, right_index --&gt; 5 Current
# values,<br />
# index --&gt; 0, left_index --&gt; 2, right_index --&gt; 5 Current
# values,<br />
# index --&gt; 0, left_index --&gt; 3, right_index --&gt; 5 Current
# values,<br />
# index --&gt; 0, left_index --&gt; 4, right_index --&gt; 5 Current
# values,<br />
# index --&gt; 1, left_index --&gt; 2, right_index --&gt; 5 Current
# values,<br />
# index --&gt; 1, left_index --&gt; 3, right_index --&gt; 4 Current
# values,<br />
# index --&gt; 2, left_index --&gt; 3, right_index --&gt; 5 Current
# values,<br />
# index --&gt; 2, left_index --&gt; 3, right_index --&gt; 4 Current
# values,<br />
# index --&gt; 3, left_index --&gt; 4, right_index --&gt; 5 [[-1, -1, 2],
# [-1, 0, 1]]</p>
# <p><em># 7. Given an integer array nums sorted in non-decreasing order,
# remove the duplicates in-place</em><br />
# <em># such that each unique element appears only once.</em></p>
# <p><em># The relative order of the elements should be kept the
# same.</em></p>
# <p>nums = [1,1,2]</p>
# <p>store={}</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>i = 0<br />
# while i &lt; len(nums):<br />
# if nums[i] notin store:<br />
# store[nums[i]]=1<br />
# i=i+1<em># move the pointer forward</em><br />
# else:<br />
# store[nums[i]]+=1<br />
# nums.pop(i) <em># no need to move pointer ahead</em></p>
# <p>print(nums)</p>
# <p>[1, 2]</p>
# <p><em># 8. You are given two integer arrays nums1 and nums2, sorted in
# non-decreasing order,</em><br />
# <em># and two integers m and n, representing the number of elements in
# nums1 and nums2 respectively.</em></p>
# <p><em># The final sorted array should not be returned by the function,
# but instead be stored inside the array nums1.</em></p>
# <p><em># To accommodate this, nums1 has a length of m + n, where the
# first m elements denote the elements that</em><br />
# <em># should be merged, and the last n elements are set to 0 and should
# be ignored. nums2 has a length of n.</em></p>
# <p>nums1=[1,2,3,0,0,0]<br />
# m=3<br />
# nums2=[2,5,6]<br />
# n=3</p>
# <p>right1=m-1<br />
# right2=n-1<br />
# right = m+n-1</p>
# <p>while right1&gt;=0and right2&gt;=0:<br />
# if nums1[right1]&gt;nums2[right2]:<br />
# nums1[right]=nums1[right1]<br />
# right1=right1-1<br />
# else:<br />
# nums1[right]=nums2[right2]<br />
# right2=right2-1<br />
# right=right-1</p>
# <p>while right2&gt;=0:<br />
# nums1[right]=nums2[right2]<br />
# right2=right2-1<br />
# right=right-1</p>
# <p>print(nums1)</p>
# <p>[1, 2, 2, 3, 5, 6]</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p><em># 9. Given an integer array nums, rotate the array to the right
# by k steps, where k is non-negative.</em></p>
# <p>nums = [1,2,3,4,5,6,7]<br />
# k = 3</p>
# <p>if k&gt;len(nums):<br />
# k = k%len(nums)</p>
# <p>nums[:] = nums[-k:]+nums[:-k]<br />
# nums</p>
# <p>[5, 6, 7, 1, 2, 3, 4]</p>
# <p><em># 10. Write function to reverse an first elements of an array,
# given start and end index</em></p>
# <p>nums = [1,2,3,4,5,6,7]</p>
# <p>def reverse_array(nums, left, right):<br />
# while left&lt;right:<br />
# nums[left], nums[right] = nums[right], nums[left] left=left+1<br />
# right=right-1</p>
# <p>return nums</p>
# <p>reverse_array(nums, 0, len(nums)-1)</p>
# <p>[7, 6, 5, 4, 3, 2, 1]</p>
# <p><em># 11. Use reverse_array to rotate array to the right by k steps,
# where k is non-negative.</em></p>
# <p>nums = [1,2,3,4,5,6,7]<br />
# k = 3</p>
# <p>if k&gt;len(nums):<br />
# k=k%len(nums)</p>
# <p>nums = reverse_array(nums, 0, len(nums)-1) print(nums)</p>
# <p><em># reverse first k elements</em><br />
# nums = reverse_array(nums, 0, k-1)<br />
# print(nums)</p>
# <p><em># reverse remaining elements</em><br />
# nums = reverse_array(nums, k, len(nums)-1) print(nums)</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>[7, 6, 5, 4, 3, 2, 1]<br />
# [5, 6, 7, 4, 3, 2, 1]<br />
# [5, 6, 7, 1, 2, 3, 4]</p>
# <p><em># 12. Given an array of positive integers nums and a positive
# integer target,</em><br />
# <em># return the minimal length of a subarray whose sum is greater than
# or equal to target.</em></p>
# <p>nums = [2,3,1,2,4,3]<br />
# target = 7</p>
# <p>n = len(nums)<br />
# left = 0<br />
# total = 0<em>#current total sum of the window</em> min_len =
# float("inf")</p>
# <p>for right inrange(n):<br />
# total = total + nums[right]</p>
# <p>while total&gt;=target:<br />
# if right-left+1&lt;min_len:<br />
# start, end = left, right<br />
# min_len = min(min_len, right-left+1) total = total - nums[left]<br />
# left=left+1</p>
# <p>print(nums[start:end+1])<br />
# print(min_len)</p>
# <p>[4, 3]</p>
# </blockquote>
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th>2</th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
# <blockquote>
# <p><em># 13. Given an array of positive integers nums and a positive
# integer target,</em><br />
# <em># return the maximum length of a subarray whose sum is greater than
# or equal to target.</em></p>
# <p>nums = [2,3,2,2,4,3]<br />
# target = 7</p>
# <p>n = len(nums)<br />
# left=0<br />
# total = 0<em># current value of the sum</em> max_len = 0</p>
# <p>for right inrange(n):<br />
# total = total + nums[right] <em># as we iterate in the for loop, window
# keeps spanning and</em><br />
# <em># total value keeps increasing</em></p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p><em># but, we have to control when total goes greater than
# target</em> while total &gt;= target:<br />
# if right-left+1 &gt; max_len:<br />
# start, end = left, right<br />
# max_len = right-left+1<br />
# total = total - nums[left]<br />
# left=left+1</p>
# <p>print(nums[start:end+1])</p>
# <p>[2, 3, 2]</p>
# <p><em># 14. You are given an array of integers nums, there is a sliding
# window of size k which is moving</em><br />
# <em># from the very left of the array to the very right. You can only
# see the k numbers in the window.</em></p>
# <p><em># Each time the sliding window moves right by one position.
# Return the max sliding window.</em></p>
# <p>nums = [1,3,-1,-3,5,3,6,7]<br />
# k = 3</p>
# <p>left = 0<br />
# right=k-1<br />
# n = len(nums)<br />
# result = []</p>
# <p>print("length : {}".format(n))</p>
# <p>while right&lt;n:<br />
# print("window --&gt; {}".format(nums[left:right+1])) print("\t right
# --&gt; {}".format(right))<br />
# result.append(int(np.max(nums[left:right+1]))) left=left+1<br />
# right=right+1</p>
# <p>print(result)</p>
# <p>length : 8<br />
# window --&gt; [1, 3, -1]<br />
# right --&gt; 2<br />
# window --&gt; [3, -1, -3]<br />
# right --&gt; 3<br />
# window --&gt; [-1, -3, 5]<br />
# right --&gt; 4<br />
# window --&gt; [-3, 5, 3]<br />
# right --&gt; 5<br />
# window --&gt; [5, 3, 6]<br />
# right --&gt; 6<br />
# window --&gt; [3, 6, 7]</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>right --&gt; 7 [3, 3, 5, 5, 6, 7]</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
# <blockquote>
# <p><em># 15. Given a string s, find the length of the longest substring
# without duplicate characters.</em></p>
# <p>s = "abcabcbb"</p>
# <p>left = 0<br />
# seen =set()<br />
# max_len = 0</p>
# <p>for right inrange(len(s)):</p>
# <p>while s[right] in seen:<br />
# seen.remove(s[left])<br />
# left=left+1</p>
# <p>seen.add(s[right])<br />
# if right-left+1 &gt; max_len:<br />
# max_len = right-left+1<br />
# start, end = left, right</p>
# <p>s[start:end+1]</p>
# <p>'abc'</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
